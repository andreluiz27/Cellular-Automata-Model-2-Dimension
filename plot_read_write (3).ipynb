# %%
# %matplotlib inline

# %%
# Author: Aric Hagberg (hagberg@lanl.gov)

#    Copyright (C) 2004-2018 by
#    Aric Hagberg <hagberg@lanl.gov>
#    Dan Schult <dschult@colgate.edu>
#    Pieter Swart <swart@lanl.gov>
#    All rights reserved.
#    BSD license.

import sys

import matplotlib.pyplot as plt
import networkx as nx
from networkx.utils import not_implemented_for
import itertools
G = nx.grid_2d_graph(3, 3,periodic=True)  # 5x5 grid
try:  # Python 2.6+
    nx.write_adjlist(G, sys.stdout)  # write adjacency list to screen
except TypeError:  # Python 3.x
    nx.write_adjlist(G, sys.stdout.buffer)  # write adjacency list to screen
# write edgelist to grid.edgelist
nx.write_edgelist(G, path="grid.edgelist", delimiter=":")
# read edgelist from grid.edgelist
H = nx.read_edgelist(path="grid.edgelist", delimiter=":")

nx.draw(H)
plt.show()
# Out:
# #/home/andrenogueira/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py -f /run/user/1000/jupyter/kernel-20647bbf-92ef-49a6-b2ff-9ca27f63b640.json
# # GMT Wed Apr 17 22:18:38 2019
# #
# (0, 0) (1, 0) (0, 1) (2, 0) (0, 2)
# (0, 1) (1, 1) (0, 2) (2, 1)
# (0, 2) (1, 2) (2, 2)
# (1, 0) (2, 0) (1, 1) (1, 2)
# (1, 1) (2, 1) (1, 2)
# (1, 2) (2, 2)
# (2, 0) (2, 1) (2, 2)
# (2, 1) (2, 2)
# (2, 2)

# %%
G.neighbors((0,0))

# %%
nodes(G)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-56-3e19f0d85f82> in <module>
# ----> 1 nodes(G)
#
# NameError: name 'nodes' is not defined

# %%
G[1]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-57-2b4e9c7716ec> in <module>
# ----> 1 G[1]
#
# ~/anaconda3/lib/python3.7/site-packages/networkx/classes/graph.py in __getitem__(self, n)
#     456         AtlasView({1: {}})
#     457         """
# --> 458         return self.adj[n]
#     459
#     460     def add_node(self, node_for_adding, **attr):
#
# ~/anaconda3/lib/python3.7/site-packages/networkx/classes/coreviews.py in __getitem__(self, name)
#      79
#      80     def __getitem__(self, name):
# ---> 81         return AtlasView(self._atlas[name])
#      82
#      83     def copy(self):
#
# KeyError: 1

# %%
G.add_node(1,state="0")

# %%
nx.draw(G)
